# %% [raw]
# ---
# title: "When I asked an LLM to explain a comet’s orbit"
# description: "Do large language models truly understand astronomy or just reenact the language of understanding?"
# author: "Hanxi"
# date: "10/30/2025"
# categories:
#   - LLMs
#   - prompting
#   - News
#   - Talk with AI
# ---

# %% [markdown]
# Recently, I came across a piece of astronomy news that immediately pulled me in — the interstellar comet **3I/ATLAS had just reached its perihelion**, the closest point to the Sun in its long, mysterious journey[^1]. As someone who has always been deeply fascinated by both **science fiction** and **astronomy**, I became curious: *How would an LLM explain a scientific story like this — one built from formulas, observational limits, and an enormous amount of uncertainty?*
#
# [^1]: [Comet 3I/ATLAS](https://science.nasa.gov/solar-system/comets/3i-atlas/)
#
#
# To explore this question, I asked the model to act as a “middle-school astronomy teacher” and explain concepts like perihelion and interstellar objects. Then, I challenged it with several “beyond the textbook” questions, to see how would it explain and "reveal" something unexpected.

# %% [markdown]
# > This experiment was conducted using GPT-5.1 for educational and reflective purposes.
# The results are for analysis only and do not represent my views about astronomers, NASA, or any research community.

# %% [markdown]
# ![Image created by Gemini](cover.png)

# %% [markdown]
# ## Experiment
#
# **Prompt**: Explain this news to a curious middle-school student as you are a middle-school astronomy teacher. [Comet 3I/ATLAS reaches perihelion, begins solar transit Now hidden from Earth, the comet is being monitored by a fleet of interplanetary spacecraft during its closest approach to the Sun](https://www.astronomy.com/science/comet-3i-atlas-reaches-perihelion-begins-solar-transit/).Use simple but accurate language.
#
# **Response**:
# (I put the screenshots here since it gave me some pictures of it):
#
#
# 🛰️ Then who is watching it?
#
# Spacecraft!
# A group of interplanetary spacecraft, including solar observatories like SOHO and STEREO, have cameras that constantly watch the Sun.
# These spacecraft can see the comet as it swings by, because:
# 	•	they are not on Earth, so their view angle is different
# 	•	their cameras are trained to handle the Sun’s brightness
# 	•	they take pictures of the area around the Sun to study space weather
#
# So while we can’t see the comet from here, our robots in space can.
#
# ⸻
#
#
# <details>
# <summary><b>Click to view full response</b></summary>
#
#
# ☄️ Why is this comet special?
#
# Comet 3I/ATLAS is interstellar — meaning it came from outside our solar system.
# It’s only the third such comet we’ve ever identified.
# That makes it kind of like a visitor from another neighborhood passing through our “solar-system town.”
#
# As it gets close to the Sun:
# 	•	heat makes its ice turn to gas
# 	•	that creates a glowing tail
# 	•	scientists can study its ingredients
# 	•	which helps us learn what other star systems are made of
#
# ⸻
#
# 🧪 What scientists hope to learn
#
# By observing the comet up close during perihelion, spacecraft can help scientists:
# 	•	study how interstellar comets behave near a star
# 	•	measure what gases and dust it releases
# 	•	compare it with comets that come from our solar system
# 	•	understand what the comet’s home environment might have been like
#
# It’s like getting a sample from another solar system—without leaving ours!
#
# </details>
#
# ![Screenshot of ChatGPT-5.1 output](output1.png)
#
# ----
#
# Now we ask two deeper, reasoning-based questions:

# %% [markdown]
# **Prompt**:
# 1. If 3I/ATLAS had twice its current mass, how would that change its perihelion trajectory?
# 2. Why are scientists still uncertain about its origin even after perihelion?
#
# Give short, structured answers. If something is unknown, say “unknown” and explain why.
#
#
# **Response**:
#
# Here we go—short and to the point, teacher mode on 😄
#
# ----
#
# 1. If 3I/ATLAS had twice its current mass…
#
# Main effect on trajectory:
# 	•	Its perihelion path would be almost the same.
# 	•	The Sun’s mass is so huge compared to the comet that doubling the comet’s mass barely changes the orbit in terms of shape or closest-approach distance.
#
# Small possible differences:
# 	•	The main change might be in non-gravitational effects (like jets of gas pushing on the comet).
# 	•	A more massive comet is a bit harder to “push around,” so outgassing might change its path slightly less, but the basic trajectory would not dramatically change.
#
# ---
#
# 2. Why are scientists still unsure about its origin?
#
# Origin star system:
# 	•	Exact birthplace: unknown.
# 	•	To trace it back to a specific star, scientists need extremely precise measurements of:
# 	•	its incoming speed and direction
# 	•	how much its path was changed by outgassing and the Sun’s gravity
# 	•	the past motions of many nearby stars
#
# Why it stays unknown:
# 	1.	Measurement limits:
# 	•	Even tiny errors in the comet’s velocity or direction grow huge when you try to “rewind” its path over millions of years.
# 	2.	Non-gravitational forces:
# 	•	Jets of gas from the comet act like little thrusters.
# 	•	These are hard to model exactly, so its past path becomes fuzzy.
# 	3.	Crowded galaxy:
# 	•	Many stars have passed near the region it came from.
# 	•	Several different stars could fit the backward-tracked path within the error bars, so there’s no single clear parent star.
#
# So: scientists can say “it came from outside our solar system,” but which star system it came from is still unknown because the data and models are not precise enough over such long times.
#
# ----
#
# Great! Then what if we make the questions even harder?
#
# **Prompt**: Could 3I/ATLAS melt completely during perihelion and reform later as the same object?
# Explain your reasoning and answer in 2 paragraph.
#
# **Response**: Short answer: no, not really. Near perihelion, a comet like 3I/ATLAS doesn’t “melt” into a puddle the way ice does on Earth. Instead, its ices sublimate—they go straight from solid to gas in the vacuum of space. That gas, plus dust, is blown away by sunlight and the solar wind, forming the coma and tail. If the comet were heated so much that its entire nucleus turned to gas and dust, that material would spread out along its orbit. The particles would be moving at different speeds and directions, so they wouldn’t stay together in one solid chunk.
#
# Because of that spreading and the Sun constantly pushing on the gas and dust, it’s extremely unlikely for all that material to later gather back into the same single object. Some bits might clump slightly or form fragments, but they’d be smaller, irregular pieces, not the original comet. Even if some re-accumulation happened, the new body would have different mass, shape, and structure, so astronomers would treat it as a different object, not “the same comet reborn.”

# %% [markdown]
# ## Analysis
#
# The model quickly settled into the role I assigned it. When I asked it to act as a middle-school astronomy teacher, it did a solid job defining *perihelion* and *interstellar comet*, and its explanations were fluent and readable.
#
# **It explaint and answered well--at least it seems like this.**
#
# But when we look carefully at it's response:
# When I pressed it with “What would happen if the comet were twice as massive?”, the model offered confident statements about orbital changes, even though such changes depend on parameters it never asked for: velocity, approach angle, and gravitational perturbations. It did not mark these statements as hypothetical or data-dependent; it simply spoke as if the physics were certain.
# When I asked, “Why is there still uncertainty even after perihelion?”, the model produced a stylistic sentence: “uncertainty remains because space observations are inherently limited”, which is true in a general sense but does not actually answer the question. It never explained which observations of 3I/ATLAS are limited, or why this object in particular resists classification. The uncertainty became a rhetorical flourish rather than a scientific explanation.
#
# The model could list plausible-sounding factors and stitch together fragments of textbook language, yet it struggled to separate what is actually known from what is speculative or simply unknown. In other words, it was very good at imitating the language of someone who understands orbital mechanics, and much less good at showing the limits of that understanding. Also, *the model explains, but does not inquire.** It can restate known concepts clearly, yet it does not naturally ask, “What evidence supports this?” or “How certain are we?” unless it is explicitly pushed to do so.
#
# ## Takeaway
#
# This does not mean LLMs are useless for science communication. In fact, this little experiment shows the opposite: they are remarkably good at translating professional material into understandable language on demand. But it also highlights a quieter risk. Because the model is so fluent, it is easy for me, as a reader, to mistake *fluency* for *understanding*, and *confident prose* for *careful reasoning*. A real astronomer is trained to live with uncertainty while the model, by contrast, has no stake in whether the comet’s origin is truly known. It only has a stake in producing something that looks like a good answer. That gap between looking like understanding and actually understanding is exactly where human being still make effort on.
#
# 3I/ATLAS may never tell us where it came from, but at least it’s honest about being mysterious. *The LLM, unfortunately, is only honest when I remind it to be.* :)
